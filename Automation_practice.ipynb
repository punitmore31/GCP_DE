# %%
table_list = ['KAIKU_DM.KAIKU_DIM_PROFITABILITY_ROWS','KAIKU_STG.BUS_BASSET_RATED','KAIKU_STG.BUS_TELLUS_HIST','','KAIKU_STG.BUS_TELLUS_RATED','KAIKU_STG.DATA_MIPA_SOPIMUSTUOTE','KAIKU_STG.DIM_BASSET_CALLTYPE','KAIKU_STG.DIM_BASSET_CUSTOMER','KAIKU_STG.DIM_MIPA_SOPIMUSHIER','KAIKU_STG.FCT_CONTRACT_SALES_T','KAIKU_STG.FCT_FIXED_SALES_T','KAIKU_STG.FCT_MOBILE_SALES_T','KAIKU_STG.FL_ABP_BL9_BLNG_ARRANGEMENT_EXT','KAIKU_STG.FL_EMCE_NETEZZA_COMPANY_VIEW','KAIKU_STG.FL_EMCE_STG_U_BILLING_CARD','KAIKU_STG.FL_EMCE_STG_U_BUSINESS_PRODUCT','cdw-prod-6040.CENS_STG.ST_SAP_MBEW','cdw-prod-6040.CORPORATE_BUS.COMPANY','cdw-prod-6040.CORPORATE_BUS.ST_MDM_ID_COMPANY','cdw-prod-6040.ETL.DIM_UECC_AGENT','cdw-prod-6040.ETL.DIM_UECC_AGENT_LOGIN','cdw-prod-6040.ETL.ETL_INVOICE_ABP_CUSTOMER_INTERIM','cdw-prod-6040.FIRA_STG.FL_FIS_R_FCHD_KASITTELY','cdw-prod-6040.FIRA_STG.FL_FIS_R_FCHD_TIKETTI','fdw-prod-5288.INTEGRATION_STG.CTL_INTEGRATION','cdw-prod-6040.JPD_FL.FL_JPD_CHANGE_SIM_ORDER','cdw-prod-6040.JPD_FL.FL_JPD_KIRJA_NODE','cdw-prod-6040.JPD_FL.FL_JPD_KIRJA_PROFILE_VALUES_DATA','cdw-prod-6040.JPD_FL.FL_JPD_KIRJA_UC_DISCOUNTS_USES','cdw-prod-6040.JPD_FL.FL_JPD_KIRJA_UC_ELISA_ORDER_DETAILS','cdw-prod-6040.JPD_FL.FL_JPD_KIRJA_UC_ORDER_PRODUCTS','cdw-prod-6040.JPD_FL.FL_JPD_KIRJA_UC_ORDERS','cdw-prod-6040.JPD_FL.FL_JPD_ORDER_GROUP_DELIVERY','cdw-prod-6040.JPD_FL.FL_JPD_PHYSICALSIM','cdw-prod-6040.JPD_FL.FL_JPD_PRODUCT_ORDER_ITEM','cdw-prod-6040.JPD_FL.FL_JPD_TICKETS','cdw-prod-6040.JPD_FL.FL_JPD_TITO_AGENT_ACTIONS','cdw-prod-6040.JPD_FL.FL_PREPAID_ACCOUNT_COST','cdw-prod-6040.JPD_FL.FL_PREPAID_PAYMENT_REFILL','cdw-prod-6040.JPD_FL.FL_PREPAID_SERVICE_FEE','fdw-prod-5288.KAIKU_DM.CTL_KAIKU_REP','fdw-prod-5288.KAIKU_DM.DIM_KAIKU_CUSTOMER','fdw-prod-5288.KAIKU_DM.LKP_KAIKU_CUSTOMER_FLAGS','fdw-prod-5288.KAIKU_DM.LKP_KAIKU_PROFITABILITY_ROWS','fdw-prod-5288.KAIKU_DM.REP_QV_KAIKU_INTERIM','fdw-prod-5288.KAIKU_DM.TMP_DIM_KAIKU_CUSTOMER','fdw-prod-5288.KAIKU_DM.TMP_DIM_KAIKU_CUSTOMER_DUPL','fdw-prod-5288.KAIKU_STG.C_CONTROL_MASTER','fdw-prod-5288.KAIKU_STG.C_MASTER_BATCH_ID','fdw-prod-5288.KAIKU_STG.C_NUMBER_PREFIX_LKP','fdw-prod-5288.KAIKU_STG.C_PERIOD','fdw-prod-5288.KAIKU_STG.C_SAS_PARAMETERS','fdw-prod-5288.KAIKU_STG.DL_KAIKU_PRODUCT_HIERARCHY','fdw-prod-5288.KAIKU_STG.KAIKU_DIM_PROFITABILITY_ROWS','fdw-prod-5288.KAIKU_STG.KAIKU_PERIOD_FREEZE','fdw-prod-5288.KAIKU_STG.LKP_MSISDN_NORMALIZER','fdw-prod-5288.KAIKU_STG.SOR_PRODUCT_EXTENSION_FIXED_CATEGORIES','fdw-prod-5288.KAIKU_STG.ST_INVOICE_HEADER_ROW','fdw-prod-5288.KAIKU_STG.STG_CLIIRA_KAIKU_SMSCENTR','fdw-prod-5288.KAIKU_STG.STG_DIM_CHARGECODE','fdw-prod-5288.KAIKU_STG.STG_ELSA_ACCOUNT_LKP','fdw-prod-5288.KAIKU_STG.STG_KAIKU_PRODUCT_HIERARCHY','fdw-prod-5288.KAIKU_STG.STG_KAIKU_PROFIT_CENTER','fdw-prod-5288.KAIKU_STG.STG_MANKELI_DIM_CUST_HIERARCHY','fdw-prod-5288.KAIKU_STG.STG_MOVING_AVG_PRICE','fdw-prod-5288.KAIKU_STG.STG_ODW_BUS4_BUS_BASSET_RATED','fdw-prod-5288.KAIKU_STG.STG_ODW_BUS4_BUS_BASSET_RATED_INTERIM','fdw-prod-5288.KAIKU_STG.STG_ODW_BUS4_BUS_TELLUS_HIST_RAW','fdw-prod-5288.KAIKU_STG.STG_PREPAID_TRAFFIC_TYPES','fdw-prod-5288.KAIKU_STG.STG_PRODUCT_TYPES','fdw-prod-5288.KAIKU_STG.STG_PROFITABILITY_EVENTS','fdw-prod-5288.KAIKU_STG.STG_SAP_GL_CUSTOMER_VAT_CODE','fdw-prod-5288.KAIKU_STG.STG_SFDC_FL_ACCOUNT','fdw-prod-5288.KAIKU_STG.STG_SFDC_V_ORDERS_SERVICE','fdw-prod-5288.KAIKU_STG.STG_SVOC_SOR_CONTRACT_LKP','fdw-prod-5288.KAIKU_STG.STG_SVOC_SOR_CONTRACT_PARTY_LKP','fdw-prod-5288.KAIKU_STG.STG_SVOC_SOR_SOR_CONTRACT','fdw-prod-5288.KAIKU_STG.STG_SVOC_SOR_SOR_PARTY','fdw-prod-5288.KAIKU_STG.STG_SVOC_SOR_SOR_PARTY_CONTRACT','fdw-prod-5288.KAIKU_STG.STG_SVOC_SOR_SOR_PRODUCT','fdw-prod-5288.KAIKU_STG.TMP_SMS_IN_WORKAROUND','fdw-prod-5288.MANKELI_OWNER.DIM_ACCT_HIERARCHY','fdw-prod-5288.MANKELI_OWNER.DIM_COMPANY_CODE','fdw-prod-5288.MANKELI_OWNER.DIM_CUST_HIERARCHY','fdw-prod-5288.MANKELI_OWNER.DIM_ORDER_HIERARCHY','fdw-prod-5288.MANKELI_OWNER.DIM_ORG_HIERARCHY','fdw-prod-5288.MANKELI_OWNER.DIM_PRODUCT_HIERARCHY','fdw-prod-5288.MANKELI_OWNER.DIM_VVFIELD_HIERARCHY','fdw-prod-5288.MANKELI_OWNER.FACT_COPA','fdw-prod-5288.MANKELI_OWNER.FACT_ORDER','fdw-prod-5288.MANKELI_OWNER.FACT_REVENUE','fdw-prod-5288.MANKELI_OWNER.FACT_SAP','fdw-prod-5288.MANKELI_OWNER.FACT_SAP_LINE_ITEM','fdw-prod-5288.MANKELI_OWNER.SOR_ANLA','fdw-prod-5288.MANKELI_OWNER.SOR_ORDER_MASTER_ASSETS','fdw-prod-5288.MANKELI_OWNER.ST_ANLA','fdw-prod-5288.MDM_DQ.FL_FINANCE_V_MAP_PROFITABILITY_PRODUCT_GLPRODORG','fdw-prod-5288.MDM_DQ.FL_FINANCEINTEGRATION_V_ORGANISATION','cdw-prod-6040.MIPA_FL.FL_MIPA_TLAJIM','cdw-prod-6040.MIPA_FL.FL_MIPA_TTILAUS','cdw-prod-6040.MIPA_FL.FL_MIPA_TTITUOTE','odw-prod-4581.ODW_BUS.BUS_IMSI','odw-prod-4581.ODW_BUS.BUS_SMS','odw-prod-4581.ODW_BUS.BUS_TAP','odw-prod-4581.ODW_BUS3.BUS_MOBDATA','odw-prod-4581.ODW_BUS4.BUS_BASSET_RATED','odw-prod-4581.ODW_BUS4.BUS_TELLUS_RATED','odw-prod-4581.ODW_BUS4.BUS_TELLUS_TVR','odw-prod-4581.ODW_BUS4.DIM_BASSET_CALLTYPE','odw-prod-4581.ODW_BUS4.DIM_BASSET_CUSTOMER','odw-prod-4581.ODW_BUS4.DIM_SERVICE_DESC','odw-prod-4581.ODW_BUS4.ELISA_IN_TARIFF_CLASS','odw-prod-4581.ODW_BUS4.SU_PARAMS_HIST','odw-prod-4581.ODW_DM.FACT_NW_QUALITY_MONTH','odw-prod-4581.ODW_FL.FL_SMSC_SMS','','odw-prod-4581.ODW_SOR2.SOR_MOBIN_CALL','odw-prod-4581.ODW_SOR2.SOR_MOBIN_CON_CONP','odw-prod-4581.ODW_SOR2.SOR_PREPAID_CRS_USAGE','','odw-prod-4581.ODW_STG.ST_COMFONE_INBOUND','odw-prod-4581.ODW_STG.ST_COMFONE_OUTBOUND','odw-prod-4581.ODW_STG2.IN_CALLS','cdw-prod-6040.SFDC_FL.FL_SFDC_ACCOUNT','cdw-prod-6040.SFDC_FL.FL_SFDC_ORDER_PRODUCT','cdw-prod-6040.SFDC_FL.FL_SFDC_ORDERS','cdw-prod-6040.SFDC_FL.FL_SFDC_SERVICE_LINE_ITEM','cdw-prod-6040.SFDC_FL.FL_SFDC_SERVICES','cdw-prod-6040.SFDC_FL.FL_SFDC_SUBSCRIPTION','cdw-prod-6040.SVOC_BUS.FCT_CONTRACT_BASE_T','cdw-prod-6040.CENS_STG.ST_SAP_MBEW','cdw-prod-6040.CORPORATE_BUS.COMPANY','cdw-prod-6040.CORPORATE_BUS.ST_MDM_ID_COMPANY','cdw-prod-6040.ETL.DIM_UECC_AGENT','cdw-prod-6040.ETL.DIM_UECC_AGENT_LOGIN','cdw-prod-6040.ETL.ETL_INVOICE_ABP_CUSTOMER_INTERIM','cdw-prod-6040.FIRA_STG.FL_FIS_R_FCHD_KASITTELY','cdw-prod-6040.FIRA_STG.FL_FIS_R_FCHD_TIKETTI','fdw-prod-5288.INTEGRATION_STG.CTL_INTEGRATION','cdw-prod-6040.JPD_FL.FL_JPD_CHANGE_SIM_ORDER','cdw-prod-6040.JPD_FL.FL_JPD_KIRJA_NODE','cdw-prod-6040.JPD_FL.FL_JPD_KIRJA_PROFILE_VALUES_DATA','cdw-prod-6040.JPD_FL.FL_JPD_KIRJA_UC_DISCOUNTS_USES','cdw-prod-6040.JPD_FL.FL_JPD_KIRJA_UC_ELISA_ORDER_DETAILS','cdw-prod-6040.JPD_FL.FL_JPD_KIRJA_UC_ORDER_PRODUCTS','cdw-prod-6040.JPD_FL.FL_JPD_KIRJA_UC_ORDERS','cdw-prod-6040.JPD_FL.FL_JPD_ORDER_GROUP_DELIVERY','cdw-prod-6040.JPD_FL.FL_JPD_PHYSICALSIM','cdw-prod-6040.JPD_FL.FL_JPD_PRODUCT_ORDER_ITEM','cdw-prod-6040.JPD_FL.FL_JPD_TICKETS','cdw-prod-6040.JPD_FL.FL_JPD_TITO_AGENT_ACTIONS','cdw-prod-6040.JPD_FL.FL_PREPAID_ACCOUNT_COST','cdw-prod-6040.JPD_FL.FL_PREPAID_PAYMENT_REFILL','cdw-prod-6040.JPD_FL.FL_PREPAID_SERVICE_FEE','fdw-prod-5288.KAIKU_DM.CTL_KAIKU_REP','fdw-prod-5288.KAIKU_DM.DIM_KAIKU_CUSTOMER','fdw-prod-5288.KAIKU_DM.LKP_KAIKU_CUSTOMER_FLAGS','fdw-prod-5288.KAIKU_DM.LKP_KAIKU_PROFITABILITY_ROWS','fdw-prod-5288.KAIKU_DM.REP_QV_KAIKU_INTERIM','fdw-prod-5288.KAIKU_DM.TMP_DIM_KAIKU_CUSTOMER','fdw-prod-5288.KAIKU_DM.TMP_DIM_KAIKU_CUSTOMER_DUPL','fdw-prod-5288.KAIKU_STG.C_CONTROL_MASTER','fdw-prod-5288.KAIKU_STG.C_MASTER_BATCH_ID','fdw-prod-5288.KAIKU_STG.C_NUMBER_PREFIX_LKP','fdw-prod-5288.KAIKU_STG.C_PERIOD','fdw-prod-5288.KAIKU_STG.C_SAS_PARAMETERS','fdw-prod-5288.KAIKU_STG.DL_KAIKU_PRODUCT_HIERARCHY','fdw-prod-5288.KAIKU_STG.KAIKU_DIM_PROFITABILITY_ROWS','fdw-prod-5288.KAIKU_STG.KAIKU_PERIOD_FREEZE','fdw-prod-5288.KAIKU_STG.LKP_MSISDN_NORMALIZER','fdw-prod-5288.KAIKU_STG.SOR_PRODUCT_EXTENSION_FIXED_CATEGORIES','fdw-prod-5288.KAIKU_STG.ST_INVOICE_HEADER_ROW','fdw-prod-5288.KAIKU_STG.STG_CLIIRA_KAIKU_SMSCENTR','fdw-prod-5288.KAIKU_STG.STG_DIM_CHARGECODE','fdw-prod-5288.KAIKU_STG.STG_ELSA_ACCOUNT_LKP','fdw-prod-5288.KAIKU_STG.STG_KAIKU_PRODUCT_HIERARCHY','fdw-prod-5288.KAIKU_STG.STG_KAIKU_PROFIT_CENTER','fdw-prod-5288.KAIKU_STG.STG_MANKELI_DIM_CUST_HIERARCHY','fdw-prod-5288.KAIKU_STG.STG_MOVING_AVG_PRICE','fdw-prod-5288.KAIKU_STG.STG_ODW_BUS4_BUS_BASSET_RATED','fdw-prod-5288.KAIKU_STG.STG_ODW_BUS4_BUS_BASSET_RATED_INTERIM','fdw-prod-5288.KAIKU_STG.STG_ODW_BUS4_BUS_TELLUS_HIST_RAW','fdw-prod-5288.KAIKU_STG.STG_PREPAID_TRAFFIC_TYPES','fdw-prod-5288.KAIKU_STG.STG_PRODUCT_TYPES','fdw-prod-5288.KAIKU_STG.STG_PROFITABILITY_EVENTS','fdw-prod-5288.KAIKU_STG.STG_SAP_GL_CUSTOMER_VAT_CODE','fdw-prod-5288.KAIKU_STG.STG_SFDC_FL_ACCOUNT','fdw-prod-5288.KAIKU_STG.STG_SFDC_V_ORDERS_SERVICE','fdw-prod-5288.KAIKU_STG.STG_SVOC_SOR_CONTRACT_LKP','fdw-prod-5288.KAIKU_STG.STG_SVOC_SOR_CONTRACT_PARTY_LKP','fdw-prod-5288.KAIKU_STG.STG_SVOC_SOR_SOR_CONTRACT','fdw-prod-5288.KAIKU_STG.STG_SVOC_SOR_SOR_PARTY','fdw-prod-5288.KAIKU_STG.STG_SVOC_SOR_SOR_PARTY_CONTRACT','fdw-prod-5288.KAIKU_STG.STG_SVOC_SOR_SOR_PRODUCT','fdw-prod-5288.KAIKU_STG.TMP_SMS_IN_WORKAROUND','fdw-prod-5288.MANKELI_OWNER.DIM_ACCT_HIERARCHY','fdw-prod-5288.MANKELI_OWNER.DIM_COMPANY_CODE','fdw-prod-5288.MANKELI_OWNER.DIM_CUST_HIERARCHY','fdw-prod-5288.MANKELI_OWNER.DIM_ORDER_HIERARCHY','fdw-prod-5288.MANKELI_OWNER.DIM_ORG_HIERARCHY','fdw-prod-5288.MANKELI_OWNER.DIM_PRODUCT_HIERARCHY','fdw-prod-5288.MANKELI_OWNER.DIM_VVFIELD_HIERARCHY','fdw-prod-5288.MANKELI_OWNER.FACT_COPA','fdw-prod-5288.MANKELI_OWNER.FACT_ORDER','fdw-prod-5288.MANKELI_OWNER.FACT_REVENUE','fdw-prod-5288.MANKELI_OWNER.FACT_SAP','fdw-prod-5288.MANKELI_OWNER.FACT_SAP_LINE_ITEM','fdw-prod-5288.MANKELI_OWNER.SOR_ANLA','fdw-prod-5288.MANKELI_OWNER.SOR_ORDER_MASTER_ASSETS','fdw-prod-5288.MANKELI_OWNER.ST_ANLA','fdw-prod-5288.MDM_DQ.FL_FINANCE_V_MAP_PROFITABILITY_PRODUCT_GLPRODORG','fdw-prod-5288.MDM_DQ.FL_FINANCEINTEGRATION_V_ORGANISATION','cdw-prod-6040.MIPA_FL.FL_MIPA_TLAJIM','cdw-prod-6040.MIPA_FL.FL_MIPA_TTILAUS','cdw-prod-6040.MIPA_FL.FL_MIPA_TTITUOTE','odw-prod-4581.ODW_BUS.BUS_IMSI','odw-prod-4581.ODW_BUS.BUS_SMS','odw-prod-4581.ODW_BUS.BUS_TAP','odw-prod-4581.ODW_BUS3.BUS_MOBDATA','odw-prod-4581.ODW_BUS4.BUS_BASSET_RATED','odw-prod-4581.ODW_BUS4.BUS_TELLUS_RATED','odw-prod-4581.ODW_BUS4.BUS_TELLUS_TVR','odw-prod-4581.ODW_BUS4.DIM_BASSET_CALLTYPE','odw-prod-4581.ODW_BUS4.DIM_BASSET_CUSTOMER','odw-prod-4581.ODW_BUS4.DIM_SERVICE_DESC','odw-prod-4581.ODW_BUS4.ELISA_IN_TARIFF_CLASS','odw-prod-4581.ODW_BUS4.SU_PARAMS_HIST','odw-prod-4581.ODW_DM.FACT_NW_QUALITY_MONTH','odw-prod-4581.ODW_FL.FL_SMSC_SMS','','odw-prod-4581.ODW_SOR2.SOR_MOBIN_CALL','odw-prod-4581.ODW_SOR2.SOR_MOBIN_CON_CONP','odw-prod-4581.ODW_SOR2.SOR_PREPAID_CRS_USAGE','','odw-prod-4581.ODW_STG.ST_COMFONE_INBOUND','odw-prod-4581.ODW_STG.ST_COMFONE_OUTBOUND','odw-prod-4581.ODW_STG2.IN_CALLS','cdw-prod-6040.SFDC_FL.FL_SFDC_ACCOUNT','cdw-prod-6040.SFDC_FL.FL_SFDC_ORDER_PRODUCT','cdw-prod-6040.SFDC_FL.FL_SFDC_ORDERS','cdw-prod-6040.SFDC_FL.FL_SFDC_SERVICE_LINE_ITEM','cdw-prod-6040.SFDC_FL.FL_SFDC_SERVICES','cdw-prod-6040.SFDC_FL.FL_SFDC_SUBSCRIPTION','cdw-prod-6040.SVOC_BUS.FCT_CONTRACT_BASE_T','cdw-prod-6040.SVOC_BUS.FCT_CONTRACT_CHURN_T','cdw-prod-6040.SVOC_BUS.FCT_CONTRACT_SALES_T','cdw-prod-6040.SVOC_BUS.FCT_FIXED_BASE_T','cdw-prod-6040.SVOC_BUS.FCT_FIXED_CHURN_T','cdw-prod-6040.SVOC_BUS.FCT_FIXED_SALES_T','cdw-prod-6040.SVOC_BUS.FCT_MOBILE_BASE_T','cdw-prod-6040.SVOC_BUS.FCT_MOBILE_CHURN_T','cdw-prod-6040.SVOC_BUS.FCT_MOBILE_SALES_T','cdw-prod-6040.SVOC_SOR.SOR_CONTRACT','cdw-prod-6040.SVOC_SOR.SOR_CONTRACT_REL','cdw-prod-6040.SVOC_SOR.SOR_DEVICE_MODEL','fdw-prod-5288.GL_SOR.SOR_GL_CUSTOMER','cdw-prod-6040.SVOC_SOR.SOR_INVOICE','cdw-prod-6040.SVOC_SOR.SOR_INVOICE_HEADER','cdw-prod-6040.SVOC_SOR.SOR_INVOICE_ROW','cdw-prod-6040.SVOC_SOR.SOR_MNP','cdw-prod-6040.SVOC_SOR.SOR_PARTY','cdw-prod-6040.SVOC_SOR.SOR_PARTY_CONTRACT','cdw-prod-6040.SVOC_SOR.SOR_PRODUCT','cdw-prod-6040.SVOC_SOR.SOR_SALES','cdw-prod-6040.SVOC_SOR.SOR_SALES_ITEM','cdw-prod-6040.SVOC_SOR.TARGET_GENERIC_ABP_GLE_INFO','cdw-prod-6040.SVOC_STG.FL_EMCE_NETEZZA_COMPANY_VIEW','cdw-prod-6040.SVOC_STG.FL_EMCE_STG_U_BILLING_CARD','cdw-prod-6040.SVOC_STG.FL_EMCE_STG_U_BUSINESS_PRODUCT','cdw-prod-6040.SVOC_STG.FL_JPD_DEVICEORDER','cdw-prod-6040.SVOC_STG.FL_JPD_GSMORDERS','cdw-prod-6040.SVOC_STG.FL_JPD_HANDSETMODEL','cdw-prod-6040.SVOC_STG.FL_JPD_HANDSETORDER','cdw-prod-6040.SVOC_STG.FL_JPD_INTRATUNNUS','cdw-prod-6040.SVOC_STG.FL_JPD_PRODUCT_ORDER_GROUP','cdw-prod-6040.SVOC_STG.FL_JPD_SAP_DELIVERY','cdw-prod-6040.SVOC_STG.FL_JPD_STOCK_ITEM','cdw-prod-6040.SVOC_STG.FL_OE_DEVICE_ORDER','cdw-prod-6040.SVOC_STG.FL_OE_DEVICE_ORDER_ROW','cdw-prod-6040.SVOC_STG.ST_EP_ENRICH_FIXED','cdw-prod-6040.SVOC_STG.ST_EP_ENRICH_MOBILESALES','cdw-prod-6040.TELLUS_FL.FL_ABP_BL9_BLNG_ARRANGEMENT_EXT','cdw-prod-6040.TERRA_BUS.DATA_MIPA_SOPIMUSTUOTE','cdw-prod-6040.TERRA_BUS.DIM_BILLING_ARRANGEMENT','cdw-prod-6040.TERRA_BUS.DIM_CHARGE','cdw-prod-6040.TERRA_BUS.DIM_CLASSIFICATION','cdw-prod-6040.TERRA_BUS.DIM_CUSTOMER','cdw-prod-6040.TERRA_BUS.DIM_MIPA_SOPIMUSHIER','cdw-prod-6040.TERRA_BUS.DIM_SUBSCRIBER','cdw-prod-6040.TERRA_BUS.DIM_UECC_CALLTYPE','cdw-prod-6040.TERRA_BUS.FACT_CREDIT_LOSS','cdw-prod-6040.TERRA_BUS.FACT_UECC_KOSYSE','cdw-prod-6040.TERRA_SOR.SOR_AR1_ACCOUNT','cdw-prod-6040.TERRA_SOR.SOR_AR1_CHARGE_GROUP','cdw-prod-6040.TERRA_SOR.SOR_AR1_INVOICE','cdw-prod-6040.TERRA_SOR.SOR_SERVICE_AGREEMENT']

project_name_list = []
db_name_list = []
table_name_list = []
invalid_table_list = []
full_table_name = []

for name in table_list:
    if name != '':
        if name.count('.') != 2:
            #print(f"Skipping invalid table name: {name}")
            invalid_table_list.append(name)
            continue
        project_name = name.split('.')[0]
        project_name_list.append(project_name)
        db_name = name.split('.')[1]
        db_name_list.append(db_name)
        table_name = name.split('.')[2]
        table_name_list.append(table_name)
        full_table_name_list = f"{db_name}.{table_name}"
        full_table_name.append(full_table_name_list)

# print(f'invalid_table_list :{invalid_table_list}' )
# print(f'project_name_list:{project_name_list}')
# print(f'db_name_list:{db_name_list}')
# print(f'table_name_list:{table_name_list}')
# print(f'full_table_name:{full_table_name}')


for i in full_table_name:
    print(i)
# Out:
# CENS_STG.ST_SAP_MBEW
# CORPORATE_BUS.COMPANY
# CORPORATE_BUS.ST_MDM_ID_COMPANY
# ETL.DIM_UECC_AGENT
# ETL.DIM_UECC_AGENT_LOGIN
# ETL.ETL_INVOICE_ABP_CUSTOMER_INTERIM
# FIRA_STG.FL_FIS_R_FCHD_KASITTELY
# FIRA_STG.FL_FIS_R_FCHD_TIKETTI
# INTEGRATION_STG.CTL_INTEGRATION
# JPD_FL.FL_JPD_CHANGE_SIM_ORDER
# JPD_FL.FL_JPD_KIRJA_NODE
# JPD_FL.FL_JPD_KIRJA_PROFILE_VALUES_DATA
# JPD_FL.FL_JPD_KIRJA_UC_DISCOUNTS_USES
# JPD_FL.FL_JPD_KIRJA_UC_ELISA_ORDER_DETAILS
# JPD_FL.FL_JPD_KIRJA_UC_ORDER_PRODUCTS
# JPD_FL.FL_JPD_KIRJA_UC_ORDERS
# JPD_FL.FL_JPD_ORDER_GROUP_DELIVERY
# JPD_FL.FL_JPD_PHYSICALSIM
# JPD_FL.FL_JPD_PRODUCT_ORDER_ITEM
# JPD_FL.FL_JPD_TICKETS
# JPD_FL.FL_JPD_TITO_AGENT_ACTIONS
# JPD_FL.FL_PREPAID_ACCOUNT_COST
# JPD_FL.FL_PREPAID_PAYMENT_REFILL
# JPD_FL.FL_PREPAID_SERVICE_FEE
# KAIKU_DM.CTL_KAIKU_REP
# KAIKU_DM.DIM_KAIKU_CUSTOMER
# KAIKU_DM.LKP_KAIKU_CUSTOMER_FLAGS
# KAIKU_DM.LKP_KAIKU_PROFITABILITY_ROWS
# KAIKU_DM.REP_QV_KAIKU_INTERIM
# KAIKU_DM.TMP_DIM_KAIKU_CUSTOMER
# ...

# %%
# 1. re.search() - Find the first match
# This function searches the string for the first location of the pattern and returns a "match object" (or None if not found).

# Use: To check if a comment exists and get its details (like its text or position).
import re 

content = """

/* HI THIS IS COMMENT PART*/

THIS IS NON COMMENT PART

"""

# Your regex pattern to find the comment
pattern = r'/\*.*?\*/'
flags = re.DOTALL

match = re.search(pattern, content, flags=flags)

if match:
    print("--- Using re.search() ---")
    print(f"Found a match: {match.group(0)}")
    print(f"It starts at index: {match.start()}")
    print(f"It ends at index: {match.end()}")
else:
    print("No match found.")
# Out:
# --- Using re.search() ---
# Found a match: /* HI THIS IS COMMENT PART*/
# It starts at index: 2
# It ends at index: 30

# %%
import re 

content = """

/* HI THIS IS COMMENT PART*/

THIS IS NON COMMENT PART

"""

# Your regex pattern to find the comment
pattern = r'/\*.*?\*/'
flags = re.DOTALL
match = re.match(pattern, content, flags=flags)

print("--- Using re.match() ---")
if match:
    print("Match found at the start.")
else:
    print("No match: The string does not start with the pattern.")
# Out:
# --- Using re.match() ---
# No match: The string does not start with the pattern.

# %%
# 3. re.split() - Split by the match
# This function splits the main string into a list, using your pattern as the delimiter (the "thing to cut at").

# Use: To get the text between the comments (in this case, the text before and after).
import re 

content = """

/* HI THIS IS COMMENT PART*/

THIS IS NON COMMENT PART

"""

# Your regex pattern to find the comment
pattern = r'/\*.*?\*/'
flags = re.DOTALL

parts = re.split(pattern, content, flags=flags)

print("--- Using re.split() ---")
print(parts)
# Out:
# --- Using re.split() ---
# ['\n\n', '\n\nTHIS IS NON COMMENT PART\n\n']

# %%
import re 

content = """

/* HI THIS IS COMMENT PART*/

THIS IS NON COMMENT PART

"""

# Your regex pattern to find the comment
pattern = r'/\*.*?\*/'
flags = re.DOTALL
match = re.match(pattern, content, flags=flags)

print("--- Using re.match() ---")
if match:
    print("Match found at the start.")
else:
    print("No match: The string does not start with the pattern.")
# Out:
# --- Using re.match() ---
# No match: The string does not start with the pattern.

# %%
# 4. re.finditer() - Find all matches as an iterator
# This is the memory-efficient version of findall(). Instead of a list, it gives you an iterator of match objects (like the one you got from re.search()).

# Use: Best for large files where you might find thousands of matches and don't want to load them all into memory at once.
import re 

content = """

/* HI THIS IS COMMENT PART*/

THIS IS NON COMMENT PART

"""

# Your regex pattern to find the comment
pattern = r'/\*.*?\*/'
flags = re.DOTALL

matches_iterator = re.finditer(pattern, content, flags=flags)

print("--- Using re.finditer() ---")
for match in matches_iterator:
    print(f"Found match: {match.group(0)} at index {match.start()}")
# Out:
# --- Using re.finditer() ---
# Found match: /* HI THIS IS COMMENT PART*/ at index 2

# %%
import yaml

config = """
users:
 - name: John
   role: admin
 - name: Alice
   role: editor
 - name: Bob
   role: viewer
 - name: Eve
   role: contributor

year: 
- 2021:
   Months:
     - January
     - February
     - March
     - April
- 2023
- 2024
- 2025
city:
 tal: Amalner
 dist: jalgaon
 state: Maharashtra

server_two:
 ip: 192.168.1.20
 role: db
 location: eu-west-1
"""


    # Use .safe_load() instead of .safe_Load()
config = yaml.safe_load(config)
print(config)
print(config['year'],end="\n")
print(config['year'][0][2021]['Months'][2],end="\n")

# for key, value in config['users'].items():
    # pass 
print(f"all keys : {config.keys()}")

# print(f" users - : config['users']")

for user in config['users']:
    print(f'user: : {user}')
    print(user['name'], user['role'],end = "\n")

print("Server Two Details:")
for key, value in config['server_two'].items():
    print(f"{key}: {value}")
print("*****"* 10, "Iterating City", "*******" * 10)
print("City:")
print("*****"* 10, "Iterating City", "*******" * 10)

print(f"City details : {config['city']}")
print(f"City Details Iteration:{config['city'].items()}")


# Your data:
# year:
# - 2021:
#     Months: [...]
# - 2023
# - 2024
print("*****"* 10, "Iterating Year", "*******" * 10)
print(f"YEAR TO BE PROCESSED : {config['year']}")
for item in config['year']:
    # Check if the item is a dictionary
    if isinstance(item, dict):
        # ... process the 2021 dictionary ...
        print(f"Processing year dictionary: {item}")
        # print(f"Processing months for {year_key}")
        

    # Check if the item is an integer
    elif isinstance(item, int):
        # ... process the 2023, 2024, etc. ...
        print(f"Processing simple year: {item}")

print("*****"* 10, "End of Year Iteration", "*******" * 10)


print(f"{config.keys()}")
print("*****"* 10, "Server_two details", "*******" * 10)
print(config['server_two'])
for key , value in config['server_two'].items():
    print(f"key = {key} , values = {value}")
    print("IP Address of Server Two: ", config['server_two']['ip']) 
    print(config['server_two']['role'], config['server_two']['location'])
# Out:
# {'users': [{'name': 'John', 'role': 'admin'}, {'name': 'Alice', 'role': 'editor'}, {'name': 'Bob', 'role': 'viewer'}, {'name': 'Eve', 'role': 'contributor'}], 'year': [{2021: {'Months': ['January', 'February', 'March', 'April']}}, 2023, 2024, 2025], 'city': {'tal': 'Amalner', 'dist': 'jalgaon', 'state': 'Maharashtra'}, 'server_two': {'ip': '192.168.1.20', 'role': 'db', 'location': 'eu-west-1'}}
# [{2021: {'Months': ['January', 'February', 'March', 'April']}}, 2023, 2024, 2025]
# March
# all keys : dict_keys(['users', 'year', 'city', 'server_two'])
# user: : {'name': 'John', 'role': 'admin'}
# John admin
# user: : {'name': 'Alice', 'role': 'editor'}
# Alice editor
# user: : {'name': 'Bob', 'role': 'viewer'}
# Bob viewer
# user: : {'name': 'Eve', 'role': 'contributor'}
# Eve contributor
# Server Two Details:
# ip: 192.168.1.20
# role: db
# location: eu-west-1
# ...

# %%
#COPY File From ONE directory to Another

import os
from pathlib import Path
import shutil

SOURCE_BASED_PATH = r"C:\Users\punitkumar.more\Documents\Elisa\fdw-dev\fdw-dags"
DESTINATION_BASED_PATH = (
    r"C:\Users\punitkumar.more\Documents\Elisa\gcp_de\AUTOMATION\fdw-dev\fdw-dags"
)

WORKFLOWS_TO_COPY = ["KAIKU.wf_InitPartyIdLkp", "KAIKU.wf_dynamo_kaiku_stg"]
print(WORKFLOWS_TO_COPY)


def find_case_insensitive_path(search_base_path, path_parts):
    CURRENT_PATH = search_base_path

    for parts in path_parts:
        sub_dirs = os.listdir(CURRENT_PATH)
        print(f"sub_dir : {sub_dirs}")
        for sub_dir in sub_dirs:
            if sub_dir.lower() == parts.lower():
                CURRENT_PATH = os.path.join(CURRENT_PATH, sub_dir)
                break
    return CURRENT_PATH


def copy_workflows():
    path_templates = [
        # Path("fdw") / "config" / "dag_config",
        # Path("fdw") / "config" / "task_config",
        # Path("fdw") / "sql"
        os.path.join("fdw", "config", "dag_config"),
        os.path.join("fdw", "config", "task_config"),
        os.path.join("fdw", "sql"),
    ]

    print(f"List of Path_templates : {path_templates} ")
    print(
        "---------------------------------------------------------------------------------------------------------------------------------"
    )

    for workflow_id in WORKFLOWS_TO_COPY:
        print(f"\nProcessing Wf : {workflow_id}")
        print("******" * 18)
        try:
            DIR_NAME, WF_NAME = workflow_id.split(".", 1)
        except ValueError:
            print(f"❌ ERROR: Invalid format for '{workflow_id}'. Skipping.")
            continue
        FOUND_AND_COPY = False
        for template in path_templates:
            print(f"template : {template}")
            search_base_path = os.path.join(SOURCE_BASED_PATH, template)
            print(f"search_base_path : {search_base_path}")

            source_path = find_case_insensitive_path(
                search_base_path, [DIR_NAME, WF_NAME]
            )
            print(f"source_path = {source_path}")

            if os.path.isdir(source_path):
                print("It's dorec")
                print(
                    f"printing the source {source_path} and Destinatioon path is L {search_base_path}"
                )
                relative_workflow_path = Path(source_path).relative_to(search_base_path)
                # 3. Construct the DESTINATION_PATH by joining the DESTINATION_BASED_PATH, template, and relative path
                print(f"relative_workflow_path :{relative_workflow_path}")
                DESTINATION_PATH = (
                    Path(DESTINATION_BASED_PATH) / template / relative_workflow_path
                )
                # -------------------------------------------------------------------------------------------------------------
                # DESTINATION_PATH = Path(f"{DESTINATION_BASED_PATH}") / f"{template}" / ""
                print(f"Destination Path : {DESTINATION_PATH}")
                try:
                    shutil.copytree(source_path, DESTINATION_PATH, dirs_exist_ok=True)
                    print(f"  ✅ Copied to: '{DESTINATION_PATH}'")
                except OSError as e:
                    print(f"❌Error while coping to destination")

                FOUND_AND_COPY = True

    if not FOUND_AND_COPY:
        print(
            f"No Matching Folder found for {workflow_id} in any of the configured path"
        )
    print("-" * (len(workflow_id) + 20))


if __name__ == "__main__":
    print(
        "--" * 20,
        "Code Started to Copy the folders from one directory to another",
        "--" * 20,
    )
    copy_workflows()
# Out:
# ['KAIKU.wf_InitPartyIdLkp', 'KAIKU.wf_dynamo_kaiku_stg']
# ---------------------------------------- Code Started to Copy the folders from one directory to another ----------------------------------------
# List of Path_templates : ['fdw\\config\\dag_config', 'fdw\\config\\task_config', 'fdw\\sql']
# ---------------------------------------------------------------------------------------------------------------------------------
#
# Processing Wf : KAIKU.wf_InitPartyIdLkp
# ************************************************************************************************************
# template : fdw\config\dag_config
# search_base_path : C:\Users\punitkumar.more\Documents\Elisa\fdw-dev\fdw-dags\fdw\config\dag_config
# sub_dir : ['CENS_STG', 'EXA_FINA_RO_CREDENTIALS.yaml', 'FDW_SL_OUT', 'FDW_SL_SOR', 'FDW_SL_STG', 'FDW_STG', 'INGESTION_ORACLE_TEST', 'KAIKU', 'LOOKUP_MAPPINGS_NS', 'MANKELI_NS', 'MASTER_DAGS', 'MDM_DQ', 'oracle.yaml', 'sql_server_v_costobject.yaml', 'SVOC_SOR', 'SVOC_STG']
# ...

# %% [markdown]
# ### Automation related to Excel :

# %%
import pandas as pd
import os
import pathlib as plib


FILE_PATH = r"C:\Users\punitkumar.more\Documents\Elisa\gcp_de\AUTOMATION\output\DOC2\multi_table_report.xlsx"
print("Creating the Directory if not exists : ")

print("\n")

# print(os.path.dirname(FILE_PATH))
p = plib.Path(FILE_PATH)
print(p)
print(p.parent)
p.parent.mkdir(parents=True, exist_ok=True)

emp_data = {
    "Name": ["Punit", "Ram", "Mohan", "kaira", "arun"],
    "age": [26, 25, 64, 23, 65],
}

score_data = {"score": [23, 44, 23, 53, 12]}

emp_df = pd.DataFrame(emp_data)
score_df = pd.DataFrame(score_data)

with pd.ExcelWriter(FILE_PATH, engine="openpyxl") as writer:
    emp_df.to_excel(
        writer, sheet_name="Employee_details", index=False, startrow=0, startcol=0
    )
    score_df.to_excel(
        writer, sheet_name="score_card", index=False, startrow=0, startcol=3
    )
print("Successfuly created the xlsx !👌")
# Out:
# Creating the Directory if not exists :
#
#
# C:\Users\punitkumar.more\Documents\Elisa\gcp_de\AUTOMATION\output\DOC2\multi_table_report.xlsx
# C:\Users\punitkumar.more\Documents\Elisa\gcp_de\AUTOMATION\output\DOC2
# Successfuly created the xlsx !👌

# %% [markdown]
# ### ✅ Python Script to Extract Workflow → Target Table Mapping

# %%
import pandas as pd
import os
import json  # Import json for clean printing, though a simple string works too


def extract_wf_table_mapping(file_path):
    """
    Reads an Excel file and returns a dictionary where:
    - Key = Workflow Name
    - Value = List of Target Data Tables
    """
    # NOTE: Changed from pd.read_csv to pd.read_excel based on the filename and common usage
    # If the file is genuinely a CSV, change this back to pd.read_csv
    try:
        df = pd.read_excel(file_path)
    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
        return {}
    except Exception as e:
        print(f"An error occurred reading the file: {e}")
        return {}

    # Forward fill workflow names (handles blank rows)
    # The .ffill() method copies the last valid value forward.
    df["Workflow Name"] = df["Workflow Name"].ffill()

    # Remove rows where target table is missing
    df = df.dropna(subset=["Target Data Table"])

    # Build dictionary: Workflow -> List of target tables
    wf_dict = df.groupby("Workflow Name")["Target Data Table"].apply(list).to_dict()

    return wf_dict


if __name__ == "__main__":
    excel_file = r"C:\Users\punitkumar.more\Documents\Elisa\gcp_de\AUTOMATION\input\Wf_details.csv"
    output_file = r"C:\Users\punitkumar.more\Documents\Elisa\gcp_de\AUTOMATION\output\DOC2\csv_json.txt"

    mapping = extract_wf_table_mapping(excel_file)

    # 1. Open the file ONCE outside the loop in 'w' (write) mode
    # This prevents the file from being overwritten in every iteration
    try:
        with open(output_file, "w") as writer:
            print(f"Writing output to: {output_file}")

            # Iterate through the generated dictionary
            for wf, tables in mapping.items():
                # Format the line as requested: wf name : [Table names]
                # The format is a string: "WorkflowName: ['Table1', 'Table2', ...]\n"
                output_line = f"{wf}: {tables}\n"

                # 2. Corrected Call: Call .write() on the file handle (writer)
                writer.write(output_line)

        print("\nSuccessfully wrote all workflow mappings to the file.")

    except FileNotFoundError:
        # This handles if the output directory (DOC2) doesn't exist
        print(
            f"Error: Output path not found. Please ensure the directory structure to {output_file} exists."
        )
    except Exception as e:
        print(f"An unexpected error occurred during file writing: {e}")
# Out:
# An error occurred reading the file: Excel file format cannot be determined, you must specify an engine manually.
# Writing output to: C:\Users\punitkumar.more\Documents\Elisa\gcp_de\AUTOMATION\output\DOC2\csv_json.txt
#
# Successfully wrote all workflow mappings to the file.
